# %% [markdown]
# # Rhetorical-semantic metrics walkthrough\nThis notebook is a compact guide. Run the numbered scripts for full reproduction.

# %%
from pathlib import Path\nimport pandas as pd\nROOT = Path('..')\npd.read_csv(ROOT/'data_public/primary_statistics/statistical_comparison_reviews_vs_clinical.csv').head()\n
